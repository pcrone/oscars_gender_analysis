# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

# %%
oscars = pd.read_csv('data/oscars/the_oscar_award.csv')

# %%
oscars.head(10)
# Out:
#    year_film  year_ceremony  ceremony        category  \
# 0       1927           1928         1           ACTOR
# 1       1927           1928         1           ACTOR
# 2       1927           1928         1         ACTRESS
# 3       1927           1928         1         ACTRESS
# 4       1927           1928         1         ACTRESS
# 5       1927           1928         1   ART DIRECTION
# 6       1927           1928         1   ART DIRECTION
# 7       1927           1928         1   ART DIRECTION
# 8       1927           1928         1  CINEMATOGRAPHY
# 9       1927           1928         1  CINEMATOGRAPHY
#
#                       name               film  winner
# 0      Richard Barthelmess          The Noose   False
# 1            Emil Jannings   The Last Command    True
# 2           Louise Dresser    A Ship Comes In   False
# 3             Janet Gaynor         7th Heaven    True
# 4           Gloria Swanson     Sadie Thompson   False
# 5            Rochus Gliese            Sunrise   False
# 6  William Cameron Menzies          The Dove;    True
# 7             Harry Oliver         7th Heaven   False
# 8            George Barnes  The Devil Dancer;   False
# 9           Charles Rosher            Sunrise    True

# %%
oscars_wo_actors = oscars[~(oscars['category'].str.contains('ACTOR') | oscars['category'].str.contains('ACTRESS'))]

# %% [markdown]
# # Category Clean up

# %%
oscars_wo_actors['category'].unique()
# Out:
# array(['ART DIRECTION', 'CINEMATOGRAPHY', 'DIRECTING (Comedy Picture)',
#        'DIRECTING (Dramatic Picture)', 'ENGINEERING EFFECTS',
#        'OUTSTANDING PICTURE', 'UNIQUE AND ARTISTIC PICTURE',
#        'WRITING (Adaptation)', 'WRITING (Original Story)',
#        'WRITING (Title Writing)', 'SPECIAL AWARD', 'DIRECTING', 'WRITING',
#        'OUTSTANDING PRODUCTION', 'SOUND RECORDING',
#        'SHORT SUBJECT (Cartoon)', 'SHORT SUBJECT (Comedy)',
#        'SHORT SUBJECT (Novelty)', 'ASSISTANT DIRECTOR', 'FILM EDITING',
#        'MUSIC (Scoring)', 'MUSIC (Song)', 'DANCE DIRECTION',
#        'WRITING (Screenplay)', 'SHORT SUBJECT (Color)',
#        'SHORT SUBJECT (One-reel)', 'SHORT SUBJECT (Two-reel)',
#        'IRVING G. THALBERG MEMORIAL AWARD', 'MUSIC (Original Score)',
#        'CINEMATOGRAPHY (Black-and-White)', 'CINEMATOGRAPHY (Color)',
#        'SPECIAL EFFECTS', 'ART DIRECTION (Black-and-White)',
#        'ART DIRECTION (Color)', 'WRITING (Original Screenplay)',
#        'DOCUMENTARY (Short Subject)',
#        'MUSIC (Music Score of a Dramatic Picture)',
#        'MUSIC (Scoring of a Musical Picture)',
#        'OUTSTANDING MOTION PICTURE', 'DOCUMENTARY',
#        'MUSIC (Music Score of a Dramatic or Comedy Picture)',
#        'WRITING (Original Motion Picture Story)', 'DOCUMENTARY (Feature)',
#        'BEST MOTION PICTURE', 'WRITING (Motion Picture Story)',
#        'COSTUME DESIGN (Black-and-White)', 'COSTUME DESIGN (Color)',
#        'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'WRITING (Story and Screenplay)',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'FOREIGN LANGUAGE FILM', 'WRITING (Screenplay--Adapted)',
#        'WRITING (Screenplay--Original)',
#        'JEAN HERSHOLT HUMANITARIAN AWARD', 'COSTUME DESIGN',
#        'SHORT SUBJECT (Live Action)',
#        'WRITING (Screenplay--based on material from another medium)',
#        'WRITING (Story and Screenplay--written directly for the screen)',
#        'SOUND', 'MUSIC (Music Score--substantially original)',
#        'MUSIC (Scoring of Music--adaptation or treatment)',
#        'BEST PICTURE', 'SOUND EFFECTS', 'SPECIAL VISUAL EFFECTS',
#        'MUSIC (Original Music Score)',
#        'MUSIC (Original Score--for a motion picture [not a musical])',
#        'MUSIC (Score of a Musical Picture--original or adaptation)',
#        'MUSIC (Song--Original for the Picture)',
#        'WRITING (Story and Screenplay--based on material not previously published or produced)',
#        'MUSIC (Original Song Score)',
#        'WRITING (Story and Screenplay--based on factual material or material not previously published or produced)',
#        'MUSIC (Original Dramatic Score)',
#        'MUSIC (Scoring: Adaptation and Original Song Score)',
#        'SHORT SUBJECT (Animated)',
#        'SPECIAL ACHIEVEMENT AWARD (Visual Effects)',
#        'MUSIC (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)',
#        'SHORT FILM (Animated)', 'SHORT FILM (Live Action)',
#        'WRITING (Screenplay Adapted from Other Material)',
#        'MUSIC (Original Song)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects)',
#        'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)',
#        'WRITING (Screenplay Written Directly for the Screen--based on factual material or on story material not previously published or produced)',
#        'VISUAL EFFECTS', 'SPECIAL ACHIEVEMENT AWARD',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects Editing)',
#        'MUSIC (Adaptation Score)',
#        'WRITING (Screenplay Based on Material from Another Medium)',
#        'WRITING (Screenplay Written Directly for the Screen)',
#        'MUSIC (Original Song Score and Its Adaptation -or- Adaptation Score)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Editing)',
#        'SHORT FILM (Dramatic Live Action)', 'MAKEUP',
#        'SOUND EFFECTS EDITING',
#        'MUSIC (Original Song Score or Adaptation Score)',
#        'WRITING (Screenplay Based on Material Previously Produced or Published)',
#        'MUSIC (Original Musical or Comedy Score)', 'SOUND EDITING',
#        'ANIMATED FEATURE FILM', 'WRITING (Adapted Screenplay)',
#        'SOUND MIXING', 'MAKEUP AND HAIRSTYLING', 'PRODUCTION DESIGN',
#        'INTERNATIONAL FEATURE FILM', 'DOCUMENTARY FEATURE FILM',
#        'DOCUMENTARY SHORT FILM', 'GORDON E. SAWYER AWARD',
#        'AWARD OF COMMENDATION'], dtype=object)

# %%
oscars_wo_actors['category_clean'] = oscars_wo_actors['category']
# Out:
# /var/folders/hl/m6_sqfln4rz_clzgydgpr1lh0000gn/T/ipykernel_68473/3313081630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oscars_wo_actors['category_clean'] = oscars_wo_actors['category']

# %%
# Clean up music category

oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*music.*(song).*'), 'category_clean'] = 'MUSIC (Song)'
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*music.*(score|scoring).*'), 'category_clean'] = 'MUSIC (Score)'

# %%
# Clean up sound

oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*sound.*'), 'category_clean'] = 'SOUND'

# %%
# Clean up make up

oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*makeup.*'), 'category_clean'] = 'MAKEUP AND HAIRSTYLING'

# %%
# Clean up cinematography

oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*cinematography.*'), 'category_clean'] = 'CINEMATOGRAPHY'

# %%
# Clean up visual effects

oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*visual.*effect.*'), 'category_clean'] = 'VISUAL EFFECTS'

# %%
# Clean up writing 
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*writing.*'), 'category_clean'] = 'WRITING'

# %%
# Clean up directing 
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*directing.*'), 'category_clean'] = 'DIRECTING'

# %%
# Clean up production
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*(production)|(art direction).*'), 'category_clean'] = 'PRODUCTION DESIGN'

# %%
# Clean up costume design 
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*costume.*'), 'category_clean'] = 'COSTUME DESIGN'

# %%
# Clean up documentary
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*documentary.*'), 'category_clean'] = 'DOCUMENTARY'

# %%
# Clean up short subject
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*short subject.*'), 'category_clean'] = 'SHORT SUBJECT'

# %%
# Clean up best picture
oscars_wo_actors.loc[oscars_wo_actors['category'].str.lower().str.match(r'.*(outstanding.*picture)|(best.*picture).*'), 'category_clean'] = 'BEST PICTURE'

# %%
oscars_wo_actors['category_clean'].unique()
# Out:
# array(['PRODUCTION DESIGN', 'CINEMATOGRAPHY', 'DIRECTING',
#        'ENGINEERING EFFECTS', 'BEST PICTURE',
#        'UNIQUE AND ARTISTIC PICTURE', 'WRITING', 'SPECIAL AWARD', 'SOUND',
#        'SHORT SUBJECT', 'ASSISTANT DIRECTOR', 'FILM EDITING',
#        'MUSIC (Score)', 'MUSIC (Song)', 'DANCE DIRECTION',
#        'IRVING G. THALBERG MEMORIAL AWARD', 'SPECIAL EFFECTS',
#        'DOCUMENTARY', 'COSTUME DESIGN',
#        'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'FOREIGN LANGUAGE FILM', 'JEAN HERSHOLT HUMANITARIAN AWARD',
#        'VISUAL EFFECTS', 'SHORT FILM (Animated)',
#        'SHORT FILM (Live Action)', 'SPECIAL ACHIEVEMENT AWARD',
#        'SHORT FILM (Dramatic Live Action)', 'MAKEUP AND HAIRSTYLING',
#        'ANIMATED FEATURE FILM', 'INTERNATIONAL FEATURE FILM',
#        'GORDON E. SAWYER AWARD', 'AWARD OF COMMENDATION'], dtype=object)

# %%
filtered_categories = [
    'IRVING G. THALBERG MEMORIAL AWARD',
    'HONORARY FOREIGN LANGUAGE FILM AWARD', 
    'HONORARY AWARD',
    'JEAN HERSHOLT HUMANITARIAN AWARD',
    'GORDON E. SAWYER AWARD', 
    'AWARD OF COMMENDATION'
]

# %%
oscars_wo_actors = oscars_wo_actors[~oscars_wo_actors['category_clean'].isin(filtered_categories)]

# %% [markdown]
# # Name Cleanup

# %%
oscars_wo_actors['name'].fillna(value='No Name', inplace=True)
oscars_wo_actors[oscars_wo_actors['name'].str.match(r'.+\s(by|and|&|,|;)\s.+')]
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 288         1934           1935         7                MUSIC (Scoring)
# 289         1934           1935         7                MUSIC (Scoring)
# 290         1934           1935         7                MUSIC (Scoring)
# 291         1934           1935         7                   MUSIC (Song)
# 292         1934           1935         7                   MUSIC (Song)
# ...          ...            ...       ...                            ...
# 10880       2023           2024        96  WRITING (Original Screenplay)
# 10881       2023           2024        96  WRITING (Original Screenplay)
# 10882       2023           2024        96  WRITING (Original Screenplay)
# 10883       2023           2024        96  WRITING (Original Screenplay)
# 10884       2023           2024        96  WRITING (Original Screenplay)
#
#                                                     name                film  \
# 288    RKO Radio Studio Music Department, Max Steiner...    The Gay Divorcee
# 289    RKO Radio Studio Music Department, Max Steiner...     The Lost Patrol
# 290    Columbia Studio Music Department, Louis Silver...   One Night of Love
# 291    Music by Vincent Youmans; Lyrics by Edward Eli...  Flying Down to Rio
# 292         Music by Con Conrad; Lyrics by Herb Magidson    The Gay Divorcee
# ...                                                  ...                 ...
# 10880       Screenplay - Justine Triet and Arthur Harari   Anatomy of a Fall
# 10881                         Written by David Hemingson       The Holdovers
# 10882            Written by Bradley Cooper & Josh Singer             Maestro
# 10883  Screenplay by Samy Burch; Story by Samy Burch ...        May December
# 10884                             Written by Celine Song          Past Lives
#
#        winner category_clean
# 288     False  MUSIC (Score)
# 289     False  MUSIC (Score)
# 290      True  MUSIC (Score)
# 291     False   MUSIC (Song)
# 292      True   MUSIC (Song)
# ...       ...            ...
# 10880    True        WRITING
# 10881   False        WRITING
# 10882   False        WRITING
# 10883   False        WRITING
# 10884   False        WRITING
#
# [2121 rows x 8 columns]

# %%
names_cleaned = oscars_wo_actors['name'].str.extract(r'(?P<name_prefix>.+by )*(?P<name_cleaned>.+)')
oscars_wo_actors = oscars_wo_actors.join(names_cleaned)

# %%
oscars_wo_actors['name_cleaned'] = oscars_wo_actors.apply(lambda row: row['name_cleaned'].split(', '), axis=1)
oscars_wo_actors = oscars_wo_actors.explode('name_cleaned')

# %%
oscars_wo_actors['name_cleaned'] = oscars_wo_actors.apply(lambda row: row['name_cleaned'].split(' and '), axis=1)
oscars_wo_actors = oscars_wo_actors.explode('name_cleaned')
oscars_wo_actors['name_cleaned'] = oscars_wo_actors.apply(lambda row: row['name_cleaned'].split(' & '), axis=1)
oscars_wo_actors = oscars_wo_actors.explode('name_cleaned')

# %%
oscars_wo_actors
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 5           1927           1928         1                  ART DIRECTION
# 6           1927           1928         1                  ART DIRECTION
# 7           1927           1928         1                  ART DIRECTION
# 8           1927           1928         1                 CINEMATOGRAPHY
# 9           1927           1928         1                 CINEMATOGRAPHY
# ...          ...            ...       ...                            ...
# 10882       2023           2024        96  WRITING (Original Screenplay)
# 10882       2023           2024        96  WRITING (Original Screenplay)
# 10883       2023           2024        96  WRITING (Original Screenplay)
# 10883       2023           2024        96  WRITING (Original Screenplay)
# 10884       2023           2024        96  WRITING (Original Screenplay)
#
#                                                     name               film  \
# 5                                          Rochus Gliese            Sunrise
# 6                                William Cameron Menzies          The Dove;
# 7                                           Harry Oliver         7th Heaven
# 8                                          George Barnes  The Devil Dancer;
# 9                                         Charles Rosher            Sunrise
# ...                                                  ...                ...
# 10882            Written by Bradley Cooper & Josh Singer            Maestro
# 10882            Written by Bradley Cooper & Josh Singer            Maestro
# 10883  Screenplay by Samy Burch; Story by Samy Burch ...       May December
# 10883  Screenplay by Samy Burch; Story by Samy Burch ...       May December
# 10884                             Written by Celine Song         Past Lives
#
#        winner     category_clean                          name_prefix  \
# 5       False  PRODUCTION DESIGN                                  NaN
# 6        True  PRODUCTION DESIGN                                  NaN
# 7       False  PRODUCTION DESIGN                                  NaN
# 8       False     CINEMATOGRAPHY                                  NaN
# 9        True     CINEMATOGRAPHY                                  NaN
# ...       ...                ...                                  ...
# 10882   False            WRITING                          Written by
# 10882   False            WRITING                          Written by
# 10883   False            WRITING  Screenplay by Samy Burch; Story by
# 10883   False            WRITING  Screenplay by Samy Burch; Story by
# 10884   False            WRITING                          Written by
#
#                   name_cleaned
# 5                Rochus Gliese
# 6      William Cameron Menzies
# 7                 Harry Oliver
# 8                George Barnes
# 9               Charles Rosher
# ...                        ...
# 10882           Bradley Cooper
# 10882              Josh Singer
# 10883               Samy Burch
# 10883            Alex Mechanik
# 10884              Celine Song
#
# [14936 rows x 10 columns]

# %%
oscars_wo_actors['first_name'] = oscars_wo_actors['name_cleaned'].str.extract(r'^(\w+)[- ]+.+')

# %%
oscars_wo_actors
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 5           1927           1928         1                  ART DIRECTION
# 6           1927           1928         1                  ART DIRECTION
# 7           1927           1928         1                  ART DIRECTION
# 8           1927           1928         1                 CINEMATOGRAPHY
# 9           1927           1928         1                 CINEMATOGRAPHY
# ...          ...            ...       ...                            ...
# 10882       2023           2024        96  WRITING (Original Screenplay)
# 10882       2023           2024        96  WRITING (Original Screenplay)
# 10883       2023           2024        96  WRITING (Original Screenplay)
# 10883       2023           2024        96  WRITING (Original Screenplay)
# 10884       2023           2024        96  WRITING (Original Screenplay)
#
#                                                     name               film  \
# 5                                          Rochus Gliese            Sunrise
# 6                                William Cameron Menzies          The Dove;
# 7                                           Harry Oliver         7th Heaven
# 8                                          George Barnes  The Devil Dancer;
# 9                                         Charles Rosher            Sunrise
# ...                                                  ...                ...
# 10882            Written by Bradley Cooper & Josh Singer            Maestro
# 10882            Written by Bradley Cooper & Josh Singer            Maestro
# 10883  Screenplay by Samy Burch; Story by Samy Burch ...       May December
# 10883  Screenplay by Samy Burch; Story by Samy Burch ...       May December
# 10884                             Written by Celine Song         Past Lives
#
#        winner     category_clean                          name_prefix  \
# 5       False  PRODUCTION DESIGN                                  NaN
# 6        True  PRODUCTION DESIGN                                  NaN
# 7       False  PRODUCTION DESIGN                                  NaN
# 8       False     CINEMATOGRAPHY                                  NaN
# 9        True     CINEMATOGRAPHY                                  NaN
# ...       ...                ...                                  ...
# 10882   False            WRITING                          Written by
# 10882   False            WRITING                          Written by
# 10883   False            WRITING  Screenplay by Samy Burch; Story by
# 10883   False            WRITING  Screenplay by Samy Burch; Story by
# 10884   False            WRITING                          Written by
#
#                   name_cleaned first_name
# 5                Rochus Gliese     Rochus
# 6      William Cameron Menzies    William
# 7                 Harry Oliver      Harry
# 8                George Barnes     George
# 9               Charles Rosher    Charles
# ...                        ...        ...
# 10882           Bradley Cooper    Bradley
# 10882              Josh Singer       Josh
# 10883               Samy Burch       Samy
# 10883            Alex Mechanik       Alex
# 10884              Celine Song     Celine
#
# [14936 rows x 11 columns]

# %% [markdown]
# # Match Gender

# %%
baby_names = pd.read_csv('data/oscars/NationalNames.csv')
baby_names['is_female'] = baby_names.apply(lambda row: row['Count'] if row['Gender'] == 'F' else 0, axis=1) 
baby_names['is_male'] = baby_names.apply(lambda row: row['Count'] if row['Gender'] == 'M' else 0, axis=1)

# %%
baby_names[baby_names['Name'] == 'Jonathan']
# Out:
#               Id      Name  Year Gender  Count  is_female  is_male
# 1356        1357  Jonathan  1880      M     18          0       18
# 3306        3307  Jonathan  1881      M     21          0       21
# 5302        5303  Jonathan  1882      M     27          0       27
# 7556        7557  Jonathan  1883      M     17          0       17
# 9708        9709  Jonathan  1884      M     21          0       21
# ...          ...       ...   ...    ...    ...        ...      ...
# 1745004  1745005  Jonathan  2012      M   9329          0     9329
# 1768437  1768438  Jonathan  2013      F     12         12        0
# 1778418  1778419  Jonathan  2013      M   8507          0     8507
# 1802812  1802813  Jonathan  2014      F     10         10        0
# 1811499  1811500  Jonathan  2014      M   8035          0     8035
#
# [196 rows x 7 columns]

# %%
baby_names_agg = baby_names.groupby('Name').agg(female=('is_female', 'sum'), male=('is_male', 'sum')).reset_index('Name')

# %%
baby_names_agg[baby_names_agg['Name'] == 'Rick']
# Out:
#        Name  female   male
# 71920  Rick     135  81251

# %%
baby_names_agg['likelihood'] = baby_names_agg.apply(lambda row: row['male'] / (row['male'] + row['female']), axis=1)

# %%
def decide_gender(likelihood):
    if likelihood < 0.5:
        return 'F'
    else:
        return 'M'

baby_names_agg['gender'] = baby_names_agg['likelihood'].apply(lambda likelihood: decide_gender(likelihood))

# %%
baby_names_agg[baby_names_agg['likelihood'].between(0.1, 0.9)]
# Out:
#           Name  female  male  likelihood gender
# 103    Aalijah     107   155    0.591603      M
# 135     Aamari      67    88    0.567742      M
# 189      Aaren     282   717    0.717718      M
# 190     Aareon      10    33    0.767442      M
# 195     Aarian      40    76    0.655172      M
# ...        ...     ...   ...         ...    ...
# 93747    Zyian      49    35    0.416667      F
# 93750    Zyien      12    48    0.800000      M
# 93754    Zyion     131   629    0.827632      M
# 93838     Zyon     500  1946    0.795585      M
# 93853    Zyree      16    51    0.761194      M
#
# [4571 rows x 5 columns]

# %%
baby_names_agg = baby_names_agg.rename(columns={'Name' : 'first_name'})

# %%
oscars_w_genders = oscars_wo_actors.merge(baby_names_agg[['first_name', 'gender']], how='left', on='first_name')

# %%
oscars_w_genders[oscars_w_genders['first_name'].isin(['Luc','Marie'])]
# Out:
#        year_film  year_ceremony  ceremony                  category  \
# 3981        1956           1957        29    COSTUME DESIGN (Color)
# 11365       2005           2006        78     DOCUMENTARY (Feature)
# 13811       2018           2019        91  SHORT FILM (Live Action)
# 14821       2023           2024        96              BEST PICTURE
# 14919       2023           2024        96            VISUAL EFFECTS
#
#                                                     name  \
# 3981                                    Marie De Matteis
# 11365                     Luc Jacquet and Yves Darondeau
# 13811          Marianne Farley and Marie-Hélène Panisset
# 14821      Marie-Ange Luciani and David Thion, Producers
# 14919  Charley Henley, Luc-Ewen Martin-Fenouillet, Si...
#
#                         film  winner            category_clean name_prefix  \
# 3981           War and Peace   False            COSTUME DESIGN         NaN
# 11365  March of the Penguins    True               DOCUMENTARY         NaN
# 13811             Marguerite   False  SHORT FILM (Live Action)         NaN
# 14821      Anatomy of a Fall   False              BEST PICTURE         NaN
# 14919               Napoleon   False            VISUAL EFFECTS         NaN
#
#                      name_cleaned first_name gender
# 3981             Marie De Matteis      Marie      F
# 11365                 Luc Jacquet        Luc      M
# 13811       Marie-Hélène Panisset      Marie      F
# 14821          Marie-Ange Luciani      Marie      F
# 14919  Luc-Ewen Martin-Fenouillet        Luc      M

# %% [markdown]
# # Save Raw Dataset

# %%
# Save file
oscars_w_genders.to_csv('data/oscars/oscars_cleansed.csv')

# %% [markdown]
# # Group by Year and Ceremony

# %% [markdown]
# ## Unique Nominees
# **Note:** Unique nominees does not change the over all trend

# %%
unique_nominees = oscars_w_genders.groupby(by=['year_ceremony', 'name_cleaned']).agg(gender=('gender', 'max')).reset_index().dropna()

# %%
unique_nominees
# Out:
#        year_ceremony         name_cleaned gender
# 2               1928          Alfred Cohn      M
# 3               1928     Anthony Coldeway      M
# 4               1928            Ben Hecht      M
# 5               1928      Benjamin Glazer      M
# 6               1928       Charles Rosher      M
# ...              ...                  ...    ...
# 12601           2024        Trish Adlesic      F
# 12602           2024           Troy Quane      M
# 12604           2024  Vincent René-Lortie      M
# 12605           2024         Wes Anderson      M
# 12606           2024        Willie Burton      M
#
# [11020 rows x 3 columns]

# %%
unique_nominees.to_csv('data/oscars/unique_nominees.csv')

# %% [markdown]
# ## Category Metrics

# %%
oscars_w_genders[(oscars_w_genders['year_ceremony'] == 2024) & (oscars_w_genders['category_clean'] == 'WRITING')]
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 14922       2023           2024        96   WRITING (Adapted Screenplay)
# 14923       2023           2024        96   WRITING (Adapted Screenplay)
# 14924       2023           2024        96   WRITING (Adapted Screenplay)
# 14925       2023           2024        96   WRITING (Adapted Screenplay)
# 14926       2023           2024        96   WRITING (Adapted Screenplay)
# 14927       2023           2024        96   WRITING (Adapted Screenplay)
# 14928       2023           2024        96  WRITING (Original Screenplay)
# 14929       2023           2024        96  WRITING (Original Screenplay)
# 14930       2023           2024        96  WRITING (Original Screenplay)
# 14931       2023           2024        96  WRITING (Original Screenplay)
# 14932       2023           2024        96  WRITING (Original Screenplay)
# 14933       2023           2024        96  WRITING (Original Screenplay)
# 14934       2023           2024        96  WRITING (Original Screenplay)
# 14935       2023           2024        96  WRITING (Original Screenplay)
#
#                                                     name  \
# 14922           Written for the screen by Cord Jefferson
# 14923            Written by Greta Gerwig & Noah Baumbach
# 14924            Written by Greta Gerwig & Noah Baumbach
# 14925        Written for the screen by Christopher Nolan
# 14926                        Screenplay by Tony McNamara
# 14927                         Written by Jonathan Glazer
# 14928       Screenplay - Justine Triet and Arthur Harari
# 14929       Screenplay - Justine Triet and Arthur Harari
# 14930                         Written by David Hemingson
# 14931            Written by Bradley Cooper & Josh Singer
# 14932            Written by Bradley Cooper & Josh Singer
# 14933  Screenplay by Samy Burch; Story by Samy Burch ...
# 14934  Screenplay by Samy Burch; Story by Samy Burch ...
# 14935                             Written by Celine Song
#
#                        film  winner category_clean  \
# 14922      American Fiction    True        WRITING
# 14923                Barbie   False        WRITING
# 14924                Barbie   False        WRITING
# 14925           Oppenheimer   False        WRITING
# 14926           Poor Things   False        WRITING
# 14927  The Zone of Interest   False        WRITING
# 14928     Anatomy of a Fall    True        WRITING
# 14929     Anatomy of a Fall    True        WRITING
# 14930         The Holdovers   False        WRITING
# 14931               Maestro   False        WRITING
# 14932               Maestro   False        WRITING
# 14933          May December   False        WRITING
# 14934          May December   False        WRITING
# 14935            Past Lives   False        WRITING
#
#                                name_prefix                name_cleaned  \
# 14922           Written for the screen by               Cord Jefferson
# 14923                          Written by                 Greta Gerwig
# 14924                          Written by                Noah Baumbach
# 14925           Written for the screen by            Christopher Nolan
# 14926                       Screenplay by                Tony McNamara
# 14927                          Written by              Jonathan Glazer
# 14928                                  NaN  Screenplay - Justine Triet
# 14929                                  NaN               Arthur Harari
# 14930                          Written by              David Hemingson
# 14931                          Written by               Bradley Cooper
# 14932                          Written by                  Josh Singer
# 14933  Screenplay by Samy Burch; Story by                   Samy Burch
# 14934  Screenplay by Samy Burch; Story by                Alex Mechanik
# 14935                          Written by                  Celine Song
#
#         first_name gender
# 14922         Cord      M
# 14923        Greta      F
# 14924         Noah      M
# 14925  Christopher      M
# 14926         Tony      M
# 14927     Jonathan      M
# 14928   Screenplay    NaN
# 14929       Arthur      M
# 14930        David      M
# 14931      Bradley      M
# 14932         Josh      M
# 14933         Samy      M
# 14934         Alex      M
# 14935       Celine      F

# %%
oscars_by_year_category = (
    oscars_w_genders.groupby(by=['year_ceremony', 'category_clean', 'category'], as_index=False)
    .value_counts(['gender'])
    .pivot(index=['year_ceremony', 'category_clean', 'category'], columns=['gender'], values=['count'])
    .fillna(0)
    .reset_index()
)
oscars_by_year_category
# Out:
#        year_ceremony            category_clean                       category  \
# gender
# 0               1928              BEST PICTURE            OUTSTANDING PICTURE
# 1               1928            CINEMATOGRAPHY                 CINEMATOGRAPHY
# 2               1928                 DIRECTING     DIRECTING (Comedy Picture)
# 3               1928                 DIRECTING   DIRECTING (Dramatic Picture)
# 4               1928       ENGINEERING EFFECTS            ENGINEERING EFFECTS
# ...              ...                       ...                            ...
# 1740            2024  SHORT FILM (Live Action)       SHORT FILM (Live Action)
# 1741            2024                     SOUND                          SOUND
# 1742            2024            VISUAL EFFECTS                 VISUAL EFFECTS
# 1743            2024                   WRITING   WRITING (Adapted Screenplay)
# 1744            2024                   WRITING  WRITING (Original Screenplay)
#
#        count
# gender     F     M
# 0        0.0   1.0
# 1        0.0   3.0
# 2        0.0   2.0
# 3        0.0   3.0
# 4        0.0   3.0
# ...      ...   ...
# 1740     1.0   7.0
# 1741     0.0  19.0
# 1742     5.0  14.0
# 1743     1.0   5.0
# 1744     1.0   6.0
#
# [1745 rows x 5 columns]

# %%
oscars_w_genders[(oscars_w_genders['year_ceremony'] == 2024) & (oscars_w_genders['category'] == 'SOUND')]
# Out:
#        year_film  year_ceremony  ceremony category  \
# 14882       2023           2024        96    SOUND
# 14883       2023           2024        96    SOUND
# 14884       2023           2024        96    SOUND
# 14885       2023           2024        96    SOUND
# 14886       2023           2024        96    SOUND
# 14887       2023           2024        96    SOUND
# 14888       2023           2024        96    SOUND
# 14889       2023           2024        96    SOUND
# 14890       2023           2024        96    SOUND
# 14891       2023           2024        96    SOUND
# 14892       2023           2024        96    SOUND
# 14893       2023           2024        96    SOUND
# 14894       2023           2024        96    SOUND
# 14895       2023           2024        96    SOUND
# 14896       2023           2024        96    SOUND
# 14897       2023           2024        96    SOUND
# 14898       2023           2024        96    SOUND
# 14899       2023           2024        96    SOUND
# 14900       2023           2024        96    SOUND
# 14901       2023           2024        96    SOUND
#
#                                                     name  \
# 14882  Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom...
# 14883  Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom...
# 14884  Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom...
# 14885  Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom...
# 14886  Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom...
# 14887  Steven A. Morrow, Richard King, Jason Ruder, T...
# 14888  Steven A. Morrow, Richard King, Jason Ruder, T...
# 14889  Steven A. Morrow, Richard King, Jason Ruder, T...
# 14890  Steven A. Morrow, Richard King, Jason Ruder, T...
# 14891  Steven A. Morrow, Richard King, Jason Ruder, T...
# 14892  Chris Munro, James H. Mather, Chris Burdon and...
# 14893  Chris Munro, James H. Mather, Chris Burdon and...
# 14894  Chris Munro, James H. Mather, Chris Burdon and...
# 14895  Chris Munro, James H. Mather, Chris Burdon and...
# 14896  Willie Burton, Richard King, Gary A. Rizzo and...
# 14897  Willie Burton, Richard King, Gary A. Rizzo and...
# 14898  Willie Burton, Richard King, Gary A. Rizzo and...
# 14899  Willie Burton, Richard King, Gary A. Rizzo and...
# 14900                      Tarn Willers and Johnnie Burn
# 14901                      Tarn Willers and Johnnie Burn
#
#                                                 film  winner category_clean  \
# 14882                                    The Creator   False          SOUND
# 14883                                    The Creator   False          SOUND
# 14884                                    The Creator   False          SOUND
# 14885                                    The Creator   False          SOUND
# 14886                                    The Creator   False          SOUND
# 14887                                        Maestro   False          SOUND
# 14888                                        Maestro   False          SOUND
# 14889                                        Maestro   False          SOUND
# 14890                                        Maestro   False          SOUND
# 14891                                        Maestro   False          SOUND
# 14892  Mission: Impossible - Dead Reckoning Part One   False          SOUND
# 14893  Mission: Impossible - Dead Reckoning Part One   False          SOUND
# 14894  Mission: Impossible - Dead Reckoning Part One   False          SOUND
# 14895  Mission: Impossible - Dead Reckoning Part One   False          SOUND
# 14896                                    Oppenheimer   False          SOUND
# 14897                                    Oppenheimer   False          SOUND
# 14898                                    Oppenheimer   False          SOUND
# 14899                                    Oppenheimer   False          SOUND
# 14900                           The Zone of Interest    True          SOUND
# 14901                           The Zone of Interest    True          SOUND
#
#       name_prefix       name_cleaned first_name gender
# 14882         NaN          Ian Voigt        Ian      M
# 14883         NaN        Erik Aadahl       Erik      M
# 14884         NaN  Ethan Van der Ryn      Ethan      M
# 14885         NaN        Tom Ozanich        Tom      M
# 14886         NaN      Dean Zupancic       Dean      M
# 14887         NaN   Steven A. Morrow     Steven      M
# 14888         NaN       Richard King    Richard      M
# 14889         NaN        Jason Ruder      Jason      M
# 14890         NaN        Tom Ozanich        Tom      M
# 14891         NaN      Dean Zupancic       Dean      M
# 14892         NaN        Chris Munro      Chris      M
# 14893         NaN    James H. Mather      James      M
# 14894         NaN       Chris Burdon      Chris      M
# 14895         NaN        Mark Taylor       Mark      M
# 14896         NaN      Willie Burton     Willie      M
# 14897         NaN       Richard King    Richard      M
# 14898         NaN      Gary A. Rizzo       Gary      M
# 14899         NaN    Kevin O'Connell      Kevin      M
# 14900         NaN       Tarn Willers       Tarn    NaN
# 14901         NaN       Johnnie Burn    Johnnie      M

# %%
# drop the extra level, and rename the count columns
oscars_by_year_category.columns = ['_'.join(str(s).strip() for s in col if s) for col in oscars_by_year_category.columns]
oscars_by_year_category
# Out:
#       year_ceremony            category_clean                       category  \
# 0              1928              BEST PICTURE            OUTSTANDING PICTURE
# 1              1928            CINEMATOGRAPHY                 CINEMATOGRAPHY
# 2              1928                 DIRECTING     DIRECTING (Comedy Picture)
# 3              1928                 DIRECTING   DIRECTING (Dramatic Picture)
# 4              1928       ENGINEERING EFFECTS            ENGINEERING EFFECTS
# ...             ...                       ...                            ...
# 1740           2024  SHORT FILM (Live Action)       SHORT FILM (Live Action)
# 1741           2024                     SOUND                          SOUND
# 1742           2024            VISUAL EFFECTS                 VISUAL EFFECTS
# 1743           2024                   WRITING   WRITING (Adapted Screenplay)
# 1744           2024                   WRITING  WRITING (Original Screenplay)
#
#       count_F  count_M
# 0         0.0      1.0
# 1         0.0      3.0
# 2         0.0      2.0
# 3         0.0      3.0
# 4         0.0      3.0
# ...       ...      ...
# 1740      1.0      7.0
# 1741      0.0     19.0
# 1742      5.0     14.0
# 1743      1.0      5.0
# 1744      1.0      6.0
#
# [1745 rows x 5 columns]

# %%
oscars_by_year_category['change_ratio'] = (
    (oscars_by_year_category['count_M'] - oscars_by_year_category['count_F']) / (oscars_by_year_category['count_M'] + oscars_by_year_category['count_F'])
)

# %%
oscars_by_year_category
# Out:
#       year_ceremony            category_clean                       category  \
# 0              1928              BEST PICTURE            OUTSTANDING PICTURE
# 1              1928            CINEMATOGRAPHY                 CINEMATOGRAPHY
# 2              1928                 DIRECTING     DIRECTING (Comedy Picture)
# 3              1928                 DIRECTING   DIRECTING (Dramatic Picture)
# 4              1928       ENGINEERING EFFECTS            ENGINEERING EFFECTS
# ...             ...                       ...                            ...
# 1740           2024  SHORT FILM (Live Action)       SHORT FILM (Live Action)
# 1741           2024                     SOUND                          SOUND
# 1742           2024            VISUAL EFFECTS                 VISUAL EFFECTS
# 1743           2024                   WRITING   WRITING (Adapted Screenplay)
# 1744           2024                   WRITING  WRITING (Original Screenplay)
#
#       count_F  count_M  change_ratio
# 0         0.0      1.0      1.000000
# 1         0.0      3.0      1.000000
# 2         0.0      2.0      1.000000
# 3         0.0      3.0      1.000000
# 4         0.0      3.0      1.000000
# ...       ...      ...           ...
# 1740      1.0      7.0      0.750000
# 1741      0.0     19.0      1.000000
# 1742      5.0     14.0      0.473684
# 1743      1.0      5.0      0.666667
# 1744      1.0      6.0      0.714286
#
# [1745 rows x 6 columns]

# %% [markdown]
# ### Save Yearly Change

# %%
oscars_yearly_change = oscars_by_year_category.groupby(by=['year_ceremony']).agg(avg_change=('change_ratio', 'mean'))

# %%
oscars_yearly_change.to_csv('data/oscars/oscars_yearly_change.csv')

# %% [markdown]
# ### Save Yearly Change By Category

# %%
oscars_yearly_change_by_category = oscars_by_year_category.groupby(by=['year_ceremony', 'category_clean'], as_index=False).agg(avg_change=('change_ratio', 'mean'))

# %%
oscars_yearly_change_by_category.sort_values(by='avg_change', ascending=True)
# Out:
#       year_ceremony              category_clean  avg_change
# 1261           2019              COSTUME DESIGN        -1.0
# 1042           2006              COSTUME DESIGN        -1.0
# 922            1999              COSTUME DESIGN        -1.0
# 1298           2021  INTERNATIONAL FEATURE FILM        -1.0
# 1302           2021           PRODUCTION DESIGN        -1.0
# ...             ...                         ...         ...
# 348            1961              CINEMATOGRAPHY         1.0
# 826            1993      MAKEUP AND HAIRSTYLING         1.0
# 827            1993               MUSIC (Score)         1.0
# 829            1993           PRODUCTION DESIGN         1.0
# 0              1928                BEST PICTURE         1.0
#
# [1357 rows x 3 columns]

# %%
oscars_yearly_change_by_category.to_csv('data/oscars/oscars_yearly_change_by_category.csv')

# %%
oscars_yearly_change_by_category[oscars_yearly_change_by_category['year_ceremony'] == 1930]
# Out:
#     year_ceremony     category_clean  avg_change
# 12           1930     CINEMATOGRAPHY         1.0
# 13           1930          DIRECTING         1.0
# 14           1930  PRODUCTION DESIGN         1.0
# 15           1930              SOUND         1.0
# 16           1930            WRITING        -1.0

# %% [markdown]
# ## Yearly Metrics

# %%
oscars_yearly = oscars_w_genders.groupby(by=['year_ceremony', 'category']).agg(nominees=('name_cleaned', 'count')).reset_index()

# %%
oscars_yearly
# Out:
#       year_ceremony                       category  nominees
# 0              1928                  ART DIRECTION         3
# 1              1928                 CINEMATOGRAPHY         3
# 2              1928     DIRECTING (Comedy Picture)         2
# 3              1928   DIRECTING (Dramatic Picture)         3
# 4              1928            ENGINEERING EFFECTS         3
# ...             ...                            ...       ...
# 1815           2024       SHORT FILM (Live Action)        10
# 1816           2024                          SOUND        20
# 1817           2024                 VISUAL EFFECTS        20
# 1818           2024   WRITING (Adapted Screenplay)         6
# 1819           2024  WRITING (Original Screenplay)         8
#
# [1820 rows x 3 columns]

# %%
oscars_yearly = (
    oscars_yearly
    .groupby(by=['year_ceremony'])
    .agg(num_categories=('category', 'count'), med_nominees=('nominees', 'median'), avg_nominees=('nominees', 'mean'))
).reset_index()

# %%
oscars_yearly
# Out:
#     year_ceremony  num_categories  med_nominees  avg_nominees
# 0            1928              11           3.0      2.818182
# 1            1929               5           5.0      5.400000
# 2            1930               6           6.0      7.333333
# 3            1931               7           5.0      6.142857
# 4            1932              11           4.0      4.363636
# ..            ...             ...           ...           ...
# 91           2020              20           7.0      9.850000
# 92           2021              19           9.0     11.210526
# 93           2022              19           8.0     11.368421
# 94           2023              19           8.0     11.473684
# 95           2024              19           8.0     11.000000
#
# [96 rows x 4 columns]

# %%
oscars_yearly.to_csv('data/oscars/oscars_by_year.csv')

# %%
oscars_w_genders[(oscars_w_genders['year_ceremony'].isin(range(1980,1990))) & (oscars_w_genders['category'] == 'DIRECTING')]
# Out:
#       year_film  year_ceremony  ceremony   category                  name  \
# 7408       1979           1980        52  DIRECTING             Bob Fosse
# 7409       1979           1980        52  DIRECTING       Francis Coppola
# 7410       1979           1980        52  DIRECTING           Peter Yates
# 7411       1979           1980        52  DIRECTING         Robert Benton
# 7412       1979           1980        52  DIRECTING      Edouard Molinaro
# 7589       1980           1981        53  DIRECTING           David Lynch
# 7590       1980           1981        53  DIRECTING        Robert Redford
# 7591       1980           1981        53  DIRECTING       Martin Scorsese
# 7592       1980           1981        53  DIRECTING          Richard Rush
# 7593       1980           1981        53  DIRECTING        Roman Polanski
# 7725       1981           1982        54  DIRECTING           Louis Malle
# 7726       1981           1982        54  DIRECTING           Hugh Hudson
# 7727       1981           1982        54  DIRECTING           Mark Rydell
# 7728       1981           1982        54  DIRECTING      Steven Spielberg
# 7729       1981           1982        54  DIRECTING         Warren Beatty
# 7871       1982           1983        55  DIRECTING     Wolfgang Petersen
# 7872       1982           1983        55  DIRECTING      Steven Spielberg
# 7873       1982           1983        55  DIRECTING  Richard Attenborough
# 7874       1982           1983        55  DIRECTING        Sydney Pollack
# 7875       1982           1983        55  DIRECTING          Sidney Lumet
# 8032       1983           1984        56  DIRECTING           Peter Yates
# 8033       1983           1984        56  DIRECTING        Ingmar Bergman
# 8034       1983           1984        56  DIRECTING          Mike Nichols
# 8035       1983           1984        56  DIRECTING       Bruce Beresford
# 8036       1983           1984        56  DIRECTING       James L. Brooks
# 8182       1984           1985        57  DIRECTING          Milos Forman
# 8183       1984           1985        57  DIRECTING           Woody Allen
# 8184       1984           1985        57  DIRECTING          Roland Joffé
# 8185       1984           1985        57  DIRECTING            David Lean
# 8186       1984           1985        57  DIRECTING         Robert Benton
# 8343       1985           1986        58  DIRECTING        Hector Babenco
# 8344       1985           1986        58  DIRECTING        Sydney Pollack
# 8345       1985           1986        58  DIRECTING           John Huston
# 8346       1985           1986        58  DIRECTING        Akira Kurosawa
# 8347       1985           1986        58  DIRECTING            Peter Weir
# 8513       1986           1987        59  DIRECTING           David Lynch
# 8514       1986           1987        59  DIRECTING           Woody Allen
# 8515       1986           1987        59  DIRECTING          Roland Joffé
# 8516       1986           1987        59  DIRECTING          Oliver Stone
# 8517       1986           1987        59  DIRECTING           James Ivory
# 8665       1987           1988        60  DIRECTING           Adrian Lyne
# 8666       1987           1988        60  DIRECTING          John Boorman
# 8667       1987           1988        60  DIRECTING   Bernardo Bertolucci
# 8668       1987           1988        60  DIRECTING        Norman Jewison
# 8669       1987           1988        60  DIRECTING       Lasse Hallström
# 8809       1988           1989        61  DIRECTING      Charles Crichton
# 8810       1988           1989        61  DIRECTING       Martin Scorsese
# 8811       1988           1989        61  DIRECTING           Alan Parker
# 8812       1988           1989        61  DIRECTING        Barry Levinson
# 8813       1988           1989        61  DIRECTING          Mike Nichols
#
#                                film  winner category_clean name_prefix  \
# 7408                  All That Jazz   False      DIRECTING         NaN
# 7409                 Apocalypse Now   False      DIRECTING         NaN
# 7410                  Breaking Away   False      DIRECTING         NaN
# 7411              Kramer vs. Kramer    True      DIRECTING         NaN
# 7412             La Cage aux Folles   False      DIRECTING         NaN
# 7589               The Elephant Man   False      DIRECTING         NaN
# 7590                Ordinary People    True      DIRECTING         NaN
# 7591                    Raging Bull   False      DIRECTING         NaN
# 7592                  The Stunt Man   False      DIRECTING         NaN
# 7593                           Tess   False      DIRECTING         NaN
# 7725                  Atlantic City   False      DIRECTING         NaN
# 7726               Chariots of Fire   False      DIRECTING         NaN
# 7727                 On Golden Pond   False      DIRECTING         NaN
# 7728        Raiders of the Lost Ark   False      DIRECTING         NaN
# 7729                           Reds    True      DIRECTING         NaN
# 7871                       Das Boot   False      DIRECTING         NaN
# 7872     E.T. The Extra-Terrestrial   False      DIRECTING         NaN
# 7873                         Gandhi    True      DIRECTING         NaN
# 7874                        Tootsie   False      DIRECTING         NaN
# 7875                    The Verdict   False      DIRECTING         NaN
# 8032                    The Dresser   False      DIRECTING         NaN
# 8033              Fanny & Alexander   False      DIRECTING         NaN
# 8034                       Silkwood   False      DIRECTING         NaN
# 8035                 Tender Mercies   False      DIRECTING         NaN
# 8036            Terms of Endearment    True      DIRECTING         NaN
# 8182                        Amadeus    True      DIRECTING         NaN
# 8183            Broadway Danny Rose   False      DIRECTING         NaN
# 8184             The Killing Fields   False      DIRECTING         NaN
# 8185             A Passage to India   False      DIRECTING         NaN
# 8186            Places in the Heart   False      DIRECTING         NaN
# 8343       Kiss of the Spider Woman   False      DIRECTING         NaN
# 8344                  Out of Africa    True      DIRECTING         NaN
# 8345                 Prizzi's Honor   False      DIRECTING         NaN
# 8346                            Ran   False      DIRECTING         NaN
# 8347                        Witness   False      DIRECTING         NaN
# 8513                    Blue Velvet   False      DIRECTING         NaN
# 8514         Hannah and Her Sisters   False      DIRECTING         NaN
# 8515                    The Mission   False      DIRECTING         NaN
# 8516                        Platoon    True      DIRECTING         NaN
# 8517             A Room with a View   False      DIRECTING         NaN
# 8665               Fatal Attraction   False      DIRECTING         NaN
# 8666                 Hope and Glory   False      DIRECTING         NaN
# 8667               The Last Emperor    True      DIRECTING         NaN
# 8668                     Moonstruck   False      DIRECTING         NaN
# 8669               My Life as a Dog   False      DIRECTING         NaN
# 8809            A Fish Called Wanda   False      DIRECTING         NaN
# 8810  The Last Temptation of Christ   False      DIRECTING         NaN
# 8811            Mississippi Burning   False      DIRECTING         NaN
# 8812                       Rain Man    True      DIRECTING         NaN
# 8813                   Working Girl   False      DIRECTING         NaN
#
#               name_cleaned first_name gender
# 7408             Bob Fosse        Bob      M
# 7409       Francis Coppola    Francis      M
# 7410           Peter Yates      Peter      M
# 7411         Robert Benton     Robert      M
# 7412      Edouard Molinaro    Edouard      M
# 7589           David Lynch      David      M
# 7590        Robert Redford     Robert      M
# 7591       Martin Scorsese     Martin      M
# 7592          Richard Rush    Richard      M
# 7593        Roman Polanski      Roman      M
# 7725           Louis Malle      Louis      M
# 7726           Hugh Hudson       Hugh      M
# 7727           Mark Rydell       Mark      M
# 7728      Steven Spielberg     Steven      M
# 7729         Warren Beatty     Warren      M
# 7871     Wolfgang Petersen   Wolfgang      M
# 7872      Steven Spielberg     Steven      M
# 7873  Richard Attenborough    Richard      M
# 7874        Sydney Pollack     Sydney      F
# 7875          Sidney Lumet     Sidney      M
# 8032           Peter Yates      Peter      M
# 8033        Ingmar Bergman     Ingmar      M
# 8034          Mike Nichols       Mike      M
# 8035       Bruce Beresford      Bruce      M
# 8036       James L. Brooks      James      M
# 8182          Milos Forman      Milos      M
# 8183           Woody Allen      Woody      M
# 8184          Roland Joffé     Roland      M
# 8185            David Lean      David      M
# 8186         Robert Benton     Robert      M
# 8343        Hector Babenco     Hector      M
# 8344        Sydney Pollack     Sydney      F
# 8345           John Huston       John      M
# 8346        Akira Kurosawa      Akira      F
# 8347            Peter Weir      Peter      M
# 8513           David Lynch      David      M
# 8514           Woody Allen      Woody      M
# 8515          Roland Joffé     Roland      M
# 8516          Oliver Stone     Oliver      M
# 8517           James Ivory      James      M
# 8665           Adrian Lyne     Adrian      M
# 8666          John Boorman       John      M
# 8667   Bernardo Bertolucci   Bernardo      M
# 8668        Norman Jewison     Norman      M
# 8669       Lasse Hallström      Lasse      M
# 8809      Charles Crichton    Charles      M
# 8810       Martin Scorsese     Martin      M
# 8811           Alan Parker       Alan      M
# 8812        Barry Levinson      Barry      M
# 8813          Mike Nichols       Mike      M
